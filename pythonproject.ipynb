# %%
# !pip install yfinance

# %%
# !pip install matplotlib

# %%
import yfinance as yf
import pandas as pd

# %%
ticker = "TSLA"
data = yf.download(ticker, start="2023-01-01",end="2025-09-15")
data.reset_index(inplace=True)
data.to_csv(f"{ticker}_data.csv",index=False)
data.head()
# Out:
# /tmp/ipython-input-1439339350.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2023-01-01",end="2025-09-15")
# [*********************100%***********************]  1 of 1 completed
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   TSLA        TSLA        TSLA        TSLA       TSLA
# 0      2023-01-03  108.099998  118.800003  104.639999  118.470001  231402800
# 1      2023-01-04  113.639999  114.589996  107.519997  109.110001  180389000
# 2      2023-01-05  110.339996  111.750000  107.160004  110.510002  157986300
# 3      2023-01-06  113.059998  114.389999  101.809998  103.000000  220911100
# 4      2023-01-09  119.769997  123.519997  117.110001  118.959999  190284000

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install lxml
# !pip install pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

# %%
ticker = "TSLA"
url = f"https://www.macrotrends.net/stocks/charts/{ticker}/apple/revenue"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table", class_="historical_data_table")

rows = table.find_all("tr")

data = []
for row in rows:
    cols = row.find_all("td")
    cols = [c.text.strip() for c in cols]
    if len(cols) == 2:
        data.append(cols)

df = pd.DataFrame(data, columns=["Date", "Revenue"])

df = df.reset_index(drop=True)

print("\n----- LAST 5 ROWS -----")
print(df.tail())
# Out:
# ----- LAST 5 ROWS -----
#     Date Revenue
# 11  2013  $2,013
# 12  2012    $413
# 13  2011    $204
# 14  2010    $117
# 15  2009    $112

# %%
ticker = "GME"
data = yf.download(ticker, start="2023-01-01",end="2025-09-15")
data.reset_index(inplace=True)
data.to_csv(f"{ticker}_data.csv",index=False)
data.head()
# Out:
# /tmp/ipython-input-1954225825.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2023-01-01",end="2025-09-15")
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close       High        Low       Open   Volume
# Ticker                   GME        GME        GME        GME      GME
# 0      2023-01-03  17.200001  19.260000  17.090000  18.639999  5135200
# 1      2023-01-04  17.320000  17.930000  16.900000  17.250000  3939300
# 2      2023-01-05  16.219999  17.260000  15.890000  17.059999  6066200
# 3      2023-01-06  16.459999  16.570000  15.410000  16.000000  4823400
# 4      2023-01-09  16.379999  17.129999  16.360001  16.650000  3522600

# %%
ticker = "GME"
url = f"https://www.macrotrends.net/stocks/charts/{ticker}/apple/revenue"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table", class_="historical_data_table")

rows = table.find_all("tr")

data = []
for row in rows:
    cols = row.find_all("td")
    cols = [c.text.strip() for c in cols]
    if len(cols) == 2:
        data.append(cols)

df = pd.DataFrame(data, columns=["Date", "Revenue"])

df = df.reset_index(drop=True)

print("\n----- LAST 5 ROWS -----")
print(df.tail())
# Out:
# ----- LAST 5 ROWS -----
#     Date Revenue
# 12  2013  $8,887
# 13  2012  $9,551
# 14  2011  $9,474
# 15  2010  $9,078
# 16  2009  $8,806

# %%
import matplotlib.pyplot as plt
ticker="TSLA"
data=yf.download(ticker,period="1y")
plt.figure(figsize=(12,6))
plt.plot(data.index, data["Close"], label=f"{ticker} Closing Price", color="green")
plt.title(f"{ticker} Stock Price (Last 1 Year)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-142378183.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download(ticker,period="1y")
# [*********************100%***********************]  1 of 1 completed

# %%
ticker="BME"
data=yf.download(ticker,period="1y")
plt.figure(figsize=(12,6))
plt.plot(data.index, data["Close"], label=f"{ticker} Closing Price", color="blue")
plt.title(f"{ticker} Stock Price (Last 1 Year)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-2260623663.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download(ticker,period="1y")
# [*********************100%***********************]  1 of 1 completed
